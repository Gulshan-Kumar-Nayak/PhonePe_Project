# %%
! git clone https://github.com/PhonePe/pulse.git
# Out:
# fatal: destination path 'pulse' already exists and is not an empty directory.

# %%
import os
import json
import pandas as pd

# %%
# Table for Aggregated Transaction data for India State-wise

path = "pulse/data/aggregated/transaction/country/india/state/"

Agg_trans = {
    "State":[], "Year":[], "Quarter":[],
    "Transaction_type":[], "Transaction_count":[], "Transaction_amount":[]
}

for state in os.listdir(path):
    state_path = os.path.join(path, state)

    for year in os.listdir(state_path):
        year_path = os.path.join(state_path, year)

        for file in os.listdir(year_path):  
            if file.endswith(".json"):
                file_path = os.path.join(year_path, file)

                with open(file_path, 'r') as f:
                    data = json.load(f)

                try:
                    for i in data['data']['transactionData']:
                        Agg_trans["State"].append(state)
                        Agg_trans["Year"].append(int(year))
                        Agg_trans["Quarter"].append(int(file.strip(".json")))
                        Agg_trans["Transaction_type"].append(i['name'])
                        Agg_trans["Transaction_count"].append(i['paymentInstruments'][0]['count'])
                        Agg_trans["Transaction_amount"].append(i['paymentInstruments'][0]['amount'])
                except:
                    pass

df_Agg_trans = pd.DataFrame(Agg_trans)
df_Agg_trans

# %%
# Table for Aggregated User data for India State-wise

path = "pulse/data/aggregated/user/country/india/state/"

Agg_user = {
    "State":[], "Year":[], "Quarter":[],
    "Brand":[], "Count":[], "Percentage":[]
}

for state in os.listdir(path):
    state_path = os.path.join(path, state)

    for year in os.listdir(state_path):
        year_path = os.path.join(state_path, year)

        for file in os.listdir(year_path):
            if file.endswith(".json"):
                file_path = os.path.join(year_path, file)

                with open(file_path, 'r') as f:
                    data = json.load(f)

                try:
                    for i in data['data']['usersByDevice']:
                        Agg_user["State"].append(state)
                        Agg_user["Year"].append(int(year))
                        Agg_user["Quarter"].append(int(file.strip(".json")))
                        Agg_user["Brand"].append(i['brand'])
                        Agg_user["Count"].append(i['count'])
                        Agg_user["Percentage"].append(i['percentage'])
                except:
                    pass

df_Agg_user = pd.DataFrame(Agg_user)
df_Agg_user

# %%
# Table for Aggregated Insurance data for India State-wise

path = "pulse/data/aggregated/insurance/country/india/state/"

Agg_ins = {
    "State":[], "Year":[], "Quarter":[],
    "Insurance_type":[], "Count":[], "Amount":[]
}

for state in os.listdir(path):
    state_path = os.path.join(path, state)

    for year in os.listdir(state_path):
        year_path = os.path.join(state_path, year)

        for file in os.listdir(year_path):
            if file.endswith(".json"):
                file_path = os.path.join(year_path, file)

                with open(file_path, 'r') as f:
                    data = json.load(f)

                try:
                    for i in data['data']['transactionData']:
                        Agg_ins["State"].append(state)
                        Agg_ins["Year"].append(int(year))
                        Agg_ins["Quarter"].append(int(file.strip(".json")))
                        Agg_ins["Insurance_type"].append(i['name'])
                        Agg_ins["Count"].append(i['paymentInstruments'][0]['count'])
                        Agg_ins["Amount"].append(i['paymentInstruments'][0]['amount'])
                except:
                    pass

df_Agg_ins = pd.DataFrame(Agg_ins)
df_Agg_ins
